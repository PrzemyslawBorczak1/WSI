# %%
# %pip install numpy
# %pip install matplotlib
# %pip install imageio
# Out:
# Requirement already satisfied: numpy in c:\users\przem\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\przem\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\przem\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\przem\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: imageio in c:\users\przem\anaconda3\lib\site-packages (2.37.2)
# Requirement already satisfied: numpy in c:\users\przem\anaconda3\lib\site-packages (from imageio) (2.3.5)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\przem\anaconda3\lib\site-packages (from imageio) (12.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from __future__ import annotations
from helpers.env import SlipperyGridWorld, ACTIONS
from helpers.viz import evaluate, plot_policy, plot_value_heatmap, run_to_gif
from helpers.viz import greedy_policy_from_V
import numpy as np
import matplotlib.pyplot as plt

# %%
# Available actions
# Action mapping: 0=Up, 1=Right, 2=Down, 3=Left
print(ACTIONS)
# Out:
# (0, 1, 2, 3)

# %%
# =============================CONFIGURATION BLOCK============================= #
# |                   Change the parameters and see what happens              | #
# =============================CONFIGURATION BLOCK============================= #

# Example parameters set up for environment
num_rows = 5
num_cols = 7
start_state = (0, 0)
goal_state = (4, 6)
slip_prob = 0.2
random_seed = 987
step_reward = -1
goal_reward = 4

# VI parameters
max_number_iterations = 3000 # max number of value iterations
threshold = 1e-5 # stopping condition
gamma = 0.99 # discount factor

# Evaluation parameters
max_steps_in_env = 20 # used for episodic evaluation

# %%
# Note that states have both (row, column) and row*num_cols + column representations
# i.e., tuple(int, int) or int, see functions docstrings for details
env = SlipperyGridWorld(rows=num_rows, cols=num_cols, start=start_state, goal=goal_state,
                        step_reward=step_reward, goal_reward=goal_reward,
                        slip_prob=slip_prob, max_steps=max_steps_in_env, seed=random_seed)
s = env.reset() 

num_states = num_rows * num_cols 
num_actions = 4

Q = np.random.default_rng(random_seed).uniform(low=-0.01, high=0.01, size=(num_states, num_actions))
for state in range(num_states):
    if env.is_terminal_state(state):
        Q[state] = 0.0


alpha = 0.2
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995

rng = np.random.default_rng(random_seed)

for episode in range(max_number_iterations):
    X = env.reset(start_state)

    while not env.is_terminal_state(X):
        if rng.random() < epsilon:
            A = rng.integers(num_actions)
        else:
            A = int(np.argmax(Q[X]))

        X_next, R, done, info = env.step(A)

        if env.is_terminal_state(X_next):
            best_next_q = 0.0
        else:
            best_next_q = float(np.max(Q[X_next]))
        

        Q[X, A] += alpha * (R + gamma * best_next_q - Q[X, A])

        X = X_next

        if done:
            break

    epsilon = max(epsilon_min, epsilon * epsilon_decay)

V = np.max(Q, axis=1)

# %%
policy_plot_name = "policy_Q_learning.png"
value_plot_name = "value_Q_learning.png"
gif_name = "episode_Q_learning.gif"
n_val_episodes = 50

env.reset()

# retrieve policy from Q(s,a)
pi = np.argmax(Q, axis=1)

# visualize policy and derived V(s)
plot_policy(env, pi, filename=policy_plot_name, title="Greedy Policy from Q")
plot_value_heatmap(env, V, filename=value_plot_name, title="V(s) = max_a Q(s, a)")
plt.close("all")

# evaluate deterministic policy over multiple episodes 
metrics = evaluate(env, policy=pi, n_episodes=n_val_episodes, seed=random_seed)
print(metrics)

# save one episode to gif
run_to_gif(env, policy=pi, gif_path=gif_name, fps=6)
# Out:
# {'avg_return': -7.3, 'std_return': 2.0224, 'success_rate': 1.0, 'avg_steps': 12.3}
